# %% [markdown]
# # Comprehensive EDA Summary: Nepal Used Car Market Dataset (847 Vehicles)
#
# ## 1. Dataset Overview
# - **Size**: 847 cleaned listings
# - **Price Range**: NPR 1,50,000 → NPR 2,40,00,000
# - **Average Price**: NPR 23,42,220 (~23.4 Lakh)
# - **Median Price**: NPR 17,70,000
# - **Year Range**: 1975–2023 (average 2013.3, median 2014)
# - **Average Engine**: 1,524 CC
# - **Average Odometer**: 51,112 km
# - **Average Mileage**: 18.91 km/l
# - **No missing values** — fully cleaned dataset
#
# ## 2. Key Numerical Relationships (Correlations)
# - Price ↔ Engine CC: **+0.394 (moderate positive — bigger engines = higher price)
# - Price ↔ Odometer: -0.166 (weak negative — higher mileage slightly lowers price)
# - Engine CC ↔ Odometer: +0.104 (almost no relationship)
#
# ## 3. Price Segmentation by Engine Size (Very Clear Pattern)
#
# | Engine Category      | Count | Avg Price (NPR) | Avg Odometer | Price Premium |
# |----------------------|-------|------------------|--------------|----------------|
# | Small (≤1200 CC)     | 406   | 17,30,136       | 47,823 km    | Baseline      |
# | Medium (1201–2000 CC)| 300   | 24,49,238       | 52,154 km    | +41% vs small |
# | Large (>2000 CC)     | 141   | 38,76,979       | 58,364 km    | +124% vs small |
#
# → Clear and strong trend: every additional ~800–1000 CC adds roughly NPR 8-12 Lakh in market value.
#
# ## 4. Depreciation vs Mileage (Surprisingly Moderate)
#
# | Mileage Group         | Count | Avg Price (NPR) | Price Drop    | % Drop |
# |-----------------------|-------|------------------|---------------|--------|
# | Low (≤50k km)         | 447   | 27,34,750       | –             | –      |
# | Medium (50–150k km)   | 393   | 19,11,202       | –8,23,548     | –30.1% |
# | High (>150k km)       | 7     | 14,75,000       | –4,36,202     | –22.8% |
#
# → Depreciation is real but not dramatic. Cars lose ~30% from low to medium mileage, then only another ~23% even at very high mileage. Nepali buyers appear relatively tolerant of higher odometer readings.
#
# ## 5. Fuel Type Performance (Clear Hierarchy)
#
# | Fuel Type | Count (est.) | Avg Engine | Avg Odometer | Avg Price (NPR) | Insight                              |
# |-----------|--------------|------------|---------------|-----------------|--------------------------------------|
# | Hybrid    | ~25–30      | 1,561 CC   | 9,402 km      | 58,89,400      | Highest price, extremely low mileage |
# | Electric  | ~15–20       | 1,660 CC   | 26,828 km     | 41,32,778      | Premium pricing despite smaller engines |
# | Diesel    | ~200–250     | 2,148 CC   | 60,578 km     | 28,95,941      | Bigger engines, higher mileage, still command good money |
# | Petrol    | ~550–600     | 1,291 CC   | 48,713 km     | 20,56,419      | Most common, best balance            |
#
# → Hybrids/EVs are rare but achieve the highest prices (2.5–3× average). Diesel vehicles have significantly larger engines and higher mileage but still sell for ~40% more than petrol on average.
#
# ## 6. Top 6 Brands Performance
#
# | Brand           | Avg Engine | Avg Price | Avg Odometer | Positioning                          |
# |-----------------|------------|-----------|---------------|--------------------------------------|
# | Toyota          | 2,237 CC   | 4.65M    | 66k km       | Clear luxury/reliability premium     |
# | Kia             | 1,685 CC   | 2.97M    | 62k km       | Strong premium positioning           |
# | Hyundai         | 1,308 CC   | 2.28M    | 49k km       | Volume leader, good value            |
# | Mahindra        | 2,037 CC   | 2.00M    | 55k km       | SUV/utility focus                    |
# | Maruti Suzuki   | 1,154 CC   | 1.77M    | 47k km       | Budget king                          |
# | Tata            | 1,799 CC   | 1.54M    | 55k km       | Surprisingly low pricing despite decent engines |
#
# → Toyota commands almost 2× the market average — strongest brand premium by far.
#
# ## 7. Sweet Spot / Best Value Segment
# 276 vehicles match the "best value" criteria:
# - Engine: 1,000–1,800 CC
# - Odometer: ≤100,000 km
# - Price: ≤ median (≤17.7 Lakh)
#
# Average price in this segment: **NPR 12,04,267**
# Dominant: Petrol + Hyundai/Maruti Suzuki
# → These are the cars that offer the most engine for the money with reasonable mileage — the clear buyer sweet spot.
#
# ## Key Market Insights (Nepal Used Car Market 2025)
#
# 1. **Engine size is the strongest price driver** (stronger than mileage).
# 2. **Mileage penalty is moderate** — Nepali buyers accept higher odometer if price reflects it.
# 3. **Toyota premium is massive** — a 10+ year old Toyota often beats newer Korean cars in price.
# 4. **Hybrids/EVs command huge premiums** despite low volume — early adopter premium pricing.
# 5. **Diesel vehicles hold value well** despite higher average mileage.
# 6. **Sweet spot is 10–18L petrol cars under 100k km** — this is where most "smart buys" live (average ~12 Lakh). The data shows high-mileage diesels & Tatas are often underpriced → huge margin potential.
#
# The Nepal used car market strongly rewards larger engines and Toyota ownership, while being relatively forgiving on mileage compared to Western markets. The data shows a clear buyer preference for power over low odometer readings.
